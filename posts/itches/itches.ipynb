# %% [markdown]
# ---
# title: "fastai example"
# author: "Risheek"
# date: "2025-11-30"
# categories: [news, code, analysis]
# description: "A brief intro to fastai using the PETS dataset"
# image: 'image.jpg'
# ---

# %%
from fastai.vision.all import *

# %%
path = untar_data(URLs.PETS)/'images'

# %%
img = path.ls()[0]
img
# Out:
# Path('/Users/risheekkumar/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_167.jpg')

# %%
img = PILImage.create(img)
img
# Out:
# PILImage mode=RGB size=183x275

# %%
img.to_thumb(192)
# Out:
# <PIL.Image.Image image mode=RGB size=128x192>
